# %%
import pandas as pd

# %%
df=pd.read_csv("framingham.csv")

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns

# %%
sns.boxplot(df.education)
# Out:
# <Axes: ylabel='education'>

# %%
df['education'] = df['education'].fillna(df['education'].median())

# %%
sns.boxplot(df.cigsPerDay)
# Out:
# <Axes: ylabel='cigsPerDay'>

# %%
df['cigsPerDay'] = df['cigsPerDay'].fillna(df['cigsPerDay'].median())

# %%
sns.boxplot(df.BPMeds)
# Out:
# <Axes: ylabel='BPMeds'>

# %%
df['BPMeds'] = df['BPMeds'].fillna(df['BPMeds'].median())

# %%
sns.boxplot(df.totChol)
# Out:
# <Axes: ylabel='totChol'>

# %%
df['totChol'] = df['totChol'].fillna(df['totChol'].median())

# %%
sns.boxplot(df.BMI)
# Out:
# <Axes: ylabel='BMI'>

# %%
df['BMI']=df['BMI'].fillna(df['BMI'].median())

# %%
sns.boxplot(df.heartRate)
# Out:
# <Axes: ylabel='heartRate'>

# %%
df=df.dropna(subset=['heartRate'])

# %%
sns.boxplot(df.glucose)
# Out:
# <Axes: ylabel='glucose'>

# %%
df['glucose']=df['glucose'].fillna(df['glucose'].median())

# %%
df.isna().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.corr()
# Out:
#                      male       age  education  currentSmoker  cigsPerDay  \
# male             1.000000 -0.029451   0.017474       0.197376    0.315494
# age             -0.029451  1.000000  -0.163233      -0.214247   -0.192226
# education        0.017474 -0.163233   1.000000       0.018509    0.007794
# currentSmoker    0.197376 -0.214247   0.018509       1.000000    0.760201
# cigsPerDay       0.315494 -0.192226   0.007794       0.760201    1.000000
# BPMeds          -0.051506  0.121065  -0.010406      -0.048323   -0.044647
# prevalentStroke -0.004526  0.057705  -0.035171      -0.032973   -0.032232
# prevalentHyp     0.004910  0.306785  -0.080709      -0.103655   -0.065335
# diabetes         0.015755  0.101356  -0.038178      -0.044262   -0.036124
# totChol         -0.069453  0.260355  -0.022458      -0.046378   -0.026907
# sysBP           -0.036505  0.393864  -0.127919      -0.130732   -0.088743
# diaBP            0.058126  0.206447  -0.061881      -0.107607   -0.056575
# BMI              0.081440  0.134891  -0.135331      -0.167400   -0.092379
# heartRate       -0.116620 -0.012823  -0.053706       0.062356    0.073871
# glucose          0.009963  0.117667  -0.033892      -0.055283   -0.056942
# TenYearCHD       0.087856  0.224541  -0.052881       0.018907    0.058477
#
#                    BPMeds  prevalentStroke  prevalentHyp  diabetes   totChol  \
# male            -0.051506        -0.004526      0.004910  0.015755 -0.069453
# age              0.121065         0.057705      0.306785  0.101356  0.260355
# education       -0.010406        -0.035171     -0.080709 -0.038178 -0.022458
# currentSmoker   -0.048323        -0.032973     -0.103655 -0.044262 -0.046378
# cigsPerDay      -0.044647        -0.032232     -0.065335 -0.036124 -0.026907
# BPMeds           1.000000         0.114606      0.258826  0.051388  0.078563
# prevalentStroke  0.114606         1.000000      0.074876  0.006946  0.000115
# prevalentHyp     0.258826         0.074876      1.000000  0.077886  0.163240
# diabetes         0.051388         0.006946      0.077886  1.000000  0.040103
# totChol          0.078563         0.000115      0.163240  0.040103  1.000000
# sysBP            0.251677         0.057064      0.696569  0.111397  0.207779
# diaBP            0.192339         0.045181      0.616178  0.050307  0.163838
# BMI              0.099628         0.024282      0.300313  0.086066  0.114904
# heartRate        0.015139        -0.017676      0.147261  0.048994  0.090532
# glucose          0.049142         0.018730      0.083450  0.606523  0.045600
# TenYearCHD       0.086571         0.061894      0.176935  0.097472  0.081844
#
#                     sysBP     diaBP       BMI  heartRate   glucose  TenYearCHD
# male            -0.036505  0.058126  0.081440  -0.116620  0.009963    0.087856
# age              0.393864  0.206447  0.134891  -0.012823  0.117667    0.224541
# education       -0.127919 -0.061881 -0.135331  -0.053706 -0.033892   -0.052881
# currentSmoker   -0.130732 -0.107607 -0.167400   0.062356 -0.055283    0.018907
# cigsPerDay      -0.088743 -0.056575 -0.092379   0.073871 -0.056942    0.058477
# BPMeds           0.251677  0.192339  0.099628   0.015139  0.049142    0.086571
# prevalentStroke  0.057064  0.045181  0.024282  -0.017676  0.018730    0.061894
# prevalentHyp     0.696569  0.616178  0.300313   0.147261  0.083450    0.176935
# diabetes         0.111397  0.050307  0.086066   0.048994  0.606523    0.097472
# totChol          0.207779  0.163838  0.114904   0.090532  0.045600    0.081844
# sysBP            1.000000  0.784635  0.324948   0.182246  0.135015    0.215640
# diaBP            0.784635  1.000000  0.376809   0.181255  0.059111    0.145772
# BMI              0.324948  0.376809  1.000000   0.067540  0.082145    0.073794
# heartRate        0.182246  0.181255  0.067540   1.000000  0.087324    0.022913
# glucose          0.135015  0.059111  0.082145   0.087324  1.000000    0.121130
# TenYearCHD       0.215640  0.145772  0.073794   0.022913  0.121130    1.000000

# %%
X=df.drop(["TenYearCHD"],axis=1)
y=df.TenYearCHD

# %%
X
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose
# 0          80.0     77.0
# 1          95.0     76.0
# 2          75.0     70.0
# 3          65.0    103.0
# 4          85.0     85.0
# ...         ...      ...
# 4233       66.0     86.0
# 4234       65.0     68.0
# 4235       84.0     86.0
# 4236       86.0     78.0
# 4237       80.0    107.0
#
# [4237 rows x 15 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4233    1
# 4234    0
# 4235    0
# 4236    0
# 4237    0
# Name: TenYearCHD, Length: 4237, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (3177, 15) (1060, 15) (3177,) (1060,)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = lr.predict(X_train)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
confusion_matrix(y_train, y_train_pred)
# Out:
# array([[2694,    9],
#        [ 458,   16]])

# %%
accuracy_score(y_train, y_train_pred)
# Out:
# 0.853005980484734

# %%
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2703
#            1       0.64      0.03      0.06       474
#
#     accuracy                           0.85      3177
#    macro avg       0.75      0.52      0.49      3177
# weighted avg       0.82      0.85      0.79      3177

# %%
df.TenYearCHD.value_counts()
# Out:
# TenYearCHD
# 0    3594
# 1     643
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
smote=SMOTE(sampling_strategy="minority",random_state=42)

# %%
X_train_sm,y_train_sm=smote.fit_resample(X_train,y_train)

# %%
y_train_sm.value_counts()
# Out:
# TenYearCHD
# 1    2703
# 0    2703
# Name: count, dtype: int64

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train_sm,y_train_sm)
# Out:
# LogisticRegression()

# %%
print(classification_report(y_train_sm,lr.predict(X_train_sm)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.63      0.64      2703
#            1       0.64      0.66      0.65      2703
#
#     accuracy                           0.64      5406
#    macro avg       0.65      0.64      0.64      5406
# weighted avg       0.65      0.64      0.64      5406

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
min_max_scaler=MinMaxScaler()

# %%
scale_X_train=min_max_scaler.fit_transform(X_train_sm)
scale_X_test=min_max_scaler.transform(X_test)

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train_sm,y_train_sm)
# Out:
# LogisticRegression()

# %%
y_scale_train=lr.predict(scale_X_train)

# %%
print(classification_report(y_train_sm, y_scale_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67      2703
#            1       0.90      0.00      0.01      2703
#
#     accuracy                           0.50      5406
#    macro avg       0.70      0.50      0.34      5406
# weighted avg       0.70      0.50      0.34      5406

# %%
from sklearn.svm import SVC

# %%
sv = SVC(kernel= "poly")

# %%
sv.fit(scale_X_train,y_train_sm)
# Out:
# SVC(kernel='poly')

# %%
sv_X_train=sv.predict(scale_X_train)

# %%
print(classification_report(y_train_sm, sv_X_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74      2703
#            1       0.74      0.73      0.73      2703
#
#     accuracy                           0.74      5406
#    macro avg       0.74      0.74      0.74      5406
# weighted avg       0.74      0.74      0.74      5406
