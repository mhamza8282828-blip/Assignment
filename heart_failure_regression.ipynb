# %%
import pandas as pd

# %%
pdf=pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
pdf
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
pdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
pdf.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
pdf.duplicated().sum()
# Out:
# np.int64(0)

# %%
pdf.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
X=pdf.drop(["DEATH_EVENT"],axis=1)
y=pdf.DEATH_EVENT

# %%
X
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((224, 12), (75, 12), (224,), (75,))

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = lr.predict(X_train)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
confusion_matrix(y_train, y_train_pred)
# Out:
# array([[144,  15],
#        [ 23,  42]])

# %%
accuracy_score(y_train, y_train_pred)
# Out:
# 0.8303571428571429

# %%
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88       159
#            1       0.74      0.65      0.69        65
#
#     accuracy                           0.83       224
#    macro avg       0.80      0.78      0.79       224
# weighted avg       0.83      0.83      0.83       224

# %%
pdf.DEATH_EVENT.value_counts()
# Out:
# DEATH_EVENT
# 0    203
# 1     96
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
smote=SMOTE(sampling_strategy="minority",random_state=42)

# %%
X_train_sm,y_train_sm=smote.fit_resample(X_train,y_train)

# %%
y_train_sm.value_counts()
# Out:
# DEATH_EVENT
# 0    159
# 1    159
# Name: count, dtype: int64

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train_sm,y_train_sm)
# Out:
# LogisticRegression()

# %%
print(classification_report(y_train_sm,lr.predict(X_train_sm)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       159
#            1       0.82      0.86      0.84       159
#
#     accuracy                           0.83       318
#    macro avg       0.83      0.83      0.83       318
# weighted avg       0.83      0.83      0.83       318

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
min_max_scaler=MinMaxScaler()

# %%
scale_X_train=min_max_scaler.fit_transform(X_train_sm)
scale_X_test=min_max_scaler.transform(X_test)

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train_sm,y_train_sm)
# Out:
# LogisticRegression()

# %%
y_scale_train=lr.predict(scale_X_train)

# %%
print(classification_report(y_train_sm, y_scale_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       159
#            1       0.75      0.77      0.76       159
#
#     accuracy                           0.76       318
#    macro avg       0.76      0.76      0.76       318
# weighted avg       0.76      0.76      0.76       318

# %%
from sklearn.svm import SVC

# %%
sv = SVC(kernel= "poly")

# %%
sv.fit(scale_X_train,y_train_sm)
# Out:
# SVC(kernel='poly')

# %%
sv_X_train=sv.predict(scale_X_train)

# %%
print(classification_report(y_train_sm, sv_X_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92       159
#            1       0.89      0.96      0.93       159
#
#     accuracy                           0.92       318
#    macro avg       0.93      0.92      0.92       318
# weighted avg       0.93      0.92      0.92       318
